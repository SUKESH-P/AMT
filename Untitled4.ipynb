# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Sukkiiii/Desktop/ME_DATA/DS/AT/amazon_delivery.csv")
data.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  object
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Order_ID            0
# Agent_Age           0
# Agent_Rating       54
# Store_Latitude      0
# Store_Longitude     0
# Drop_Latitude       0
# Drop_Longitude      0
# Order_Date          0
# Order_Time          0
# Pickup_Time         0
# Weather            91
# Traffic             0
# Vehicle             0
# Area                0
# Delivery_Time       0
# Category            0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Order_ID           0
# Agent_Age          0
# Agent_Rating       0
# Store_Latitude     0
# Store_Longitude    0
# Drop_Latitude      0
# Drop_Longitude     0
# Order_Date         0
# Order_Time         0
# Pickup_Time        0
# Weather            0
# Traffic            0
# Vehicle            0
# Area               0
# Delivery_Time      0
# Category           0
# dtype: int64

# %%
plt.figure(figsize=(15, 5))  
sns.boxplot(data=data)       
plt.show()

# %%
data.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
data['Order_Time_hr'] = pd.to_datetime(data['Order_Time'], format='%H:%M:%S').dt.hour
data['Order_Time_min'] = pd.to_datetime(data['Order_Time'], format='%H:%M:%S').dt.minute
data['Order_Time_sec'] = pd.to_datetime(data['Order_Time'], format='%H:%M:%S').dt.second
data['Pickup_Time_hr'] = pd.to_datetime(data['Pickup_Time'], format='%H:%M:%S').dt.hour
data['Pickup_Time_min'] = pd.to_datetime(data['Pickup_Time'], format='%H:%M:%S').dt.minute
data['Pickup_Time_hr'] = pd.to_datetime(data['Pickup_Time'], format='%H:%M:%S').dt.second
data['Order_Date_year'] = pd.to_datetime(data['Order_Date']).dt.year
data['Order_Date_month'] = pd.to_datetime(data['Order_Date']).dt.month
data['Order_Date_day'] = pd.to_datetime(data['Order_Date']).dt.day
data.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  ...  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00  ...
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00  ...
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00  ...
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00  ...
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00  ...
#
# ...

# %%
data.drop('Order_Date',axis=1,inplace=True)
data.drop('Order_Time',axis=1,inplace=True)
data.drop('Pickup_Time',axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43594 entries, 0 to 43738
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          43594 non-null  object
#  1   Agent_Age         43594 non-null  int64
#  2   Agent_Rating      43594 non-null  float64
#  3   Store_Latitude    43594 non-null  float64
#  4   Store_Longitude   43594 non-null  float64
#  5   Drop_Latitude     43594 non-null  float64
#  6   Drop_Longitude    43594 non-null  float64
#  7   Weather           43594 non-null  object
#  8   Traffic           43594 non-null  object
#  9   Vehicle           43594 non-null  object
#  10  Area              43594 non-null  object
#  11  Delivery_Time     43594 non-null  int64
#  12  Category          43594 non-null  object
#  13  Order_Time_hr     43594 non-null  int32
#  14  Order_Time_min    43594 non-null  int32
#  15  Order_Time_sec    43594 non-null  int32
# ...

# %%
data['Vehicle'].value_counts()
# Out:
# Vehicle
# motorcycle     25486
# scooter        14590
# van             3518
# Name: count, dtype: int64

# %%
encoded_data=data

# %%
data['Delivery_Time'] = data['Delivery_Time'].astype('int64')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
encoded_data['Weather']=encoder.fit_transform(encoded_data.Weather)
encoded_data['Traffic']=encoder.fit_transform(encoded_data.Traffic)
encoded_data['Vehicle']=encoder.fit_transform(encoded_data.Vehicle)
encoded_data['Area']=encoder.fit_transform(encoded_data.Area)
encoded_data['Category']=encoder.fit_transform(encoded_data.Category)

# %%
x=encoded_data
x=encoded_data.drop('Delivery_Time',axis=1)
x=x.drop('Order_ID',axis=1)

# %%
y=encoded_data['Delivery_Time']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43594 entries, 0 to 43738
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Agent_Age         43594 non-null  int64
#  1   Agent_Rating      43594 non-null  float64
#  2   Store_Latitude    43594 non-null  float64
#  3   Store_Longitude   43594 non-null  float64
#  4   Drop_Latitude     43594 non-null  float64
#  5   Drop_Longitude    43594 non-null  float64
#  6   Weather           43594 non-null  int32
#  7   Traffic           43594 non-null  int32
#  8   Vehicle           43594 non-null  int32
#  9   Area              43594 non-null  int32
#  10  Category          43594 non-null  int32
#  11  Order_Time_hr     43594 non-null  int32
#  12  Order_Time_min    43594 non-null  int32
#  13  Order_Time_sec    43594 non-null  int32
#  14  Pickup_Time_hr    43594 non-null  int32
#  15  Pickup_Time_min   43594 non-null  int32
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (x, y,test_size=0.3, random_state=100)

# %%
X_train.shape
# Out:
# (30515, 19)

# %%
X_test.shape
# Out:
# (13079, 19)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(X_test)
predictions
# Out:
# array([151.74240996, 111.21578626, 110.34698621, ..., 143.25774654,
#        147.98083184, 124.35136458])

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# calculate these metrics by hand!
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 33.484795818634716
# MSE: 1906.883111308984
# RMSE: 43.66787275914621

# %%
r_squared = metrics.r2_score(y_test,predictions)

r_squared
# Out:
# 0.2917989112101913

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 33.48
# Mean Squared Error (MSE): 1906.88
# Root Mean Squared Error (RMSE): 43.67
# R² Score: 0.29

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Initialize the Random Forest Regressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 20.92
# Mean Squared Error (MSE): 730.98
# Root Mean Squared Error (RMSE): 27.04
# R² Score: 0.73

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameters grid
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5, 10]
}

# Perform Grid Search
grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=5, scoring="r2", n_jobs=-1)
grid_search.fit(X_train, y_train)

# Best Parameters
print("Best Parameters:", grid_search.best_params_)

# Train final model with best parameters
best_rf = RandomForestRegressor(**grid_search.best_params_, random_state=42)
best_rf.fit(X_train, y_train)

# Make predictions
y_pred_best = best_rf.predict(X_test)

# Evaluate again
r2_best = r2_score(y_test, y_pred_best)
print(f"Optimized R² Score: {r2_best:.2f}")
# Out:
# Best Parameters: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 200}
# Optimized R² Score: 0.73

# %%
feature_importances = pd.Series(rf.feature_importances_, index=x.columns).sort_values(ascending=False)
print(feature_importances)
# Out:
# Category            0.262620
# Agent_Rating        0.171114
# Weather             0.103905
# Traffic             0.097635
# Agent_Age           0.081058
# Order_Time_hr       0.055616
# Order_Date_day      0.039710
# Drop_Longitude      0.031342
# Drop_Latitude       0.030347
# Store_Longitude     0.025002
# Vehicle             0.024005
# Store_Latitude      0.023853
# Pickup_Time_min     0.019270
# Order_Time_min      0.018407
# Area                0.011024
# Order_Date_month    0.005092
# Order_Time_sec      0.000000
# Pickup_Time_hr      0.000000
# Order_Date_year     0.000000
# dtype: float64

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Initialize Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Train the model
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = gbr.predict(X_test)

# %%
# Compute evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 22.04
# Mean Squared Error (MSE): 790.79
# Root Mean Squared Error (RMSE): 28.12
# R² Score: 0.71

# %%
X_train = X_train.drop(columns=["Order_Time_sec", "Pickup_Time_hr", "Order_Date_year"])
X_test = X_test.drop(columns=["Order_Time_sec", "Pickup_Time_hr", "Order_Date_year"])

# %%
best_gbr=GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# %%
best_gbr.fit(X_train, y_train)
y_pred_best = best_gbr.predict(X_test)

# Check new performance
r2_best = r2_score(y_test, y_pred_best)
print(f"Updated R² Score: {r2_best:.2f}")
# Out:
# Updated R² Score: 0.71

# %%
brf = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
brf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_best=brf.predict(X_test)
r2_b = r2_score(y_test, y_best)
print(f"Updated R² Score: {r2_b:.2f}")
# Out:
# Updated R² Score: 0.73

# %%
import pickle

# Assume 'gbr' is your trained model (GradientBoostingRegressor)
with open("brf_model.pkl", "wb") as file:
    pickle.dump(brf, file)

# %%
import pickle

# Train model (GradientBoostingRegressor in this case)
gbr.fit(X_train, y_train)

# Save the model along with feature names
model_data = {
    "model": gbr,
    "feature_names": list(X_train.columns)  # Save feature names
}

with open("gbr_model.pkl", "wb") as file:
    pickle.dump(model_data, file)

# %%
data.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Weather  Traffic  Vehicle  ...  \
# 0      22.765049       75.912471        4        0        0  ...
# 1      13.043041       77.813237        3        1        1  ...
# 2      12.924264       77.688400        2        2        0  ...
# 3      11.053669       77.026494        4        3        0  ...
# 4      13.012793       80.289982        0        0        1  ...
#
#    Delivery_Time  Category  Order_Time_hr  Order_Time_min  Order_Time_sec  \
# ...

# %%
data['Category'].unique()
# Out:
# array([ 2,  4, 14,  3, 15, 13, 11,  0,  7,  9,  5,  1,  8,  6, 10, 12])
